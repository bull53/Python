# %%
import pandas as pd

# %%
df = pd.read_csv('regrex1 (1).csv')

# %%
df.head()
# Out:
#         y        x
# 0  6.8102   9.8492
# 1  9.8437  11.1450
# 2  4.9767   5.1209
# 3  5.0006   8.1085
# 4  3.5047   3.5599

# %%
import matplotlib.pyplot as plt

# %%
df['x'].head()
# Out:
# 0     9.8492
# 1    11.1450
# 2     5.1209
# 3     8.1085
# 4     3.5599
# Name: x, dtype: float64

# %%
df['y'].head()
# Out:
# 0    6.8102
# 1    9.8437
# 2    4.9767
# 3    5.0006
# 4    3.5047
# Name: y, dtype: float64

# %%
plt.scatter(df['x'], df['y'])

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
x=np.array(df['x']).reshape(-1,1)
y=np.array(df['y'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 x=np.array(df['x']).reshape(-1,1)
#       2 y=np.array(df['y'])
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
x=np.array(df['x']).reshape(-1,1)
y=np.array(df['y'])

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
r_sq = model.predict(x)
print(f"intercept: {model.intercept_}")
print(f"slope: {model.coef_}")
# Out:
# intercept: 2.2481427736669986
# slope: [0.46906228]

# %%
y_pred = model.predict(x)

# %%
plt.scatter(x,y)
plt.plot(x,y_pred)
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')
